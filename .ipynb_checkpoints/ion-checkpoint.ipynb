# %%
import numpy as np
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.metrics import *
from sklearn.preprocessing import StandardScaler


import tensorflow as tf
print(tf.__version__)
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.utils import normalize

tf.keras.backend.clear_session()  # For easy reset of notebook state.
# Out:
# 2.1.0

# %%
y = np.loadtxt('coef_mat_one_photon.dat')
x = np.loadtxt('coef_mat_invFFTpulse.dat')
#x = np.loadtxt('coef_mat_zero_photon.dat')
#y = np.loadtxt('ionization_probability.dat')
#x = y[:,2]
#print(ion.shape)

#plt.plot(ion[:,2],'o')
print(x.shape)
print(y.shape)
#print(y[0:1])
# standardize dataset
x = StandardScaler().fit_transform(x)
y = StandardScaler().fit_transform(y)
#x = StandardScaler().fit_transform(y.reshape(len(y),3))[:,1]
#y = StandardScaler().fit_transform(y.reshape(len(y),3))[:,2]
print("")
print(x.shape)
print(y.shape)
#print(y[0:1])
# Out:
# (100001, 40)
# (100001, 40)
#
# (100001, 40)
# (100001, 40)

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=0.05)
x_train, x_val, y_train, y_val = train_test_split(x_train,y_train, test_size=0.05263)

print("\nx:")
print(x_train.shape)
print(x_test.shape)
print(x_val.shape)

print("y:")
print(y_train.shape)
print(y_test.shape)
print(y_val.shape)

#y_test_inv = StandardScaler().fit(y_test.reshape(len(y_test),40)).inverse_transform(y_test)
#y_test_inv.shape
#plt.plot(y_test_inv)
len(y_train[:1])
# Out:
# x:
# (90000, 40)
# (5001, 40)
# (5000, 40)
# y:
# (90000, 40)
# (5001, 40)
# (5000, 40)
# 1

# %%
inputs = keras.Input(shape=x_train.shape[1:])
print("input_shape = ",inputs.shape)
print("inputs_type = ",inputs.dtype)
dense = layers.Dense(units=64, activation='relu')(inputs)
dense1 = layers.Dense(units=128, activation='relu')(dense)
dense2 = layers.Dense(units=264, activation='relu')(dense1)
#dense3 = layers.Dense(units=328, activation='relu')(dense2)
#dense4 = layers.Dense(units=428, activation='relu')(dense3)
dense5 = layers.Dense(units=328, activation='relu')(dense2)
dense6 = layers.Dense(units=228, activation='relu')(dense5)
dense7 = layers.Dense(units=128, activation='relu')(dense6)
#dense8 = layers.Dense(units=64, activation='relu')(dense7)
outputs = layers.Dense(units=40, activation='linear')(dense7)
# Out:
# input_shape =  (None, 40)
# inputs_type =  <dtype: 'float32'>

# %%
model = keras.Model(inputs=inputs, outputs=outputs, name='pol_model')
model.summary()
# Out:
# Model: "pol_model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 40)]              0
# _________________________________________________________________
# dense (Dense)                (None, 40)                1640
# _________________________________________________________________
# dense_1 (Dense)              (None, 40)                1640
# _________________________________________________________________
# dense_2 (Dense)              (None, 40)                1640
# _________________________________________________________________
# dense_3 (Dense)              (None, 40)                1640
# _________________________________________________________________
# dense_4 (Dense)              (None, 40)                1640
# _________________________________________________________________
# dense_5 (Dense)              (None, 40)                1640
# _________________________________________________________________
# dense_6 (Dense)              (None, 40)                1640
# =================================================================
# Total params: 11,480
# Trainable params: 11,480
# Non-trainable params: 0
# _________________________________________________________________

# %%
keras.utils.plot_model(model, to_file='model_with_shape_info.png', show_shapes=True)

# %%
opt= tf.keras.optimizers.Adam(lr=0.001, decay=1e-6)
model.compile(loss='mean_squared_error',
             optimizer=opt,
             metrics=['accuracy'])

# %%
history = model.fit(x_train, y_train,
          epochs=200,
          batch_size=40,
          validation_data=(x_val, y_val))
# Out:
# Train on 90000 samples, validate on 5000 samples
# Epoch 1/200
# 90000/90000 [==============================] - 3s 32us/sample - loss: 0.6662 - accuracy: 0.2147 - val_loss: 0.5701 - val_accuracy: 0.2714
# Epoch 2/200
# 90000/90000 [==============================] - 2s 27us/sample - loss: 0.5042 - accuracy: 0.3138 - val_loss: 0.4717 - val_accuracy: 0.3392
# Epoch 3/200
# 90000/90000 [==============================] - 2s 26us/sample - loss: 0
200
# 90000/90000 [==============================] - 2s 26us/sample - loss: 0.2222 - accuracy: 0.5211 - val_loss: 0.2259 - val_accuracy: 0.5176
# Epoch 91/200
# 90000/90000 [==============================] - 2s 27us/sample - loss: 0.2216 - accuracy: 0.5235 - val_loss: 0.2352 - val_accuracy: 0.5090
# Epoch 92/200
# 90000/90000 [==============================] - 2s 27us/sample - loss: 0.2210 - accuracy: 0.5229 - val_loss: 0.2220 - val_accuracy: 0.5284
# Epoch 93/200
# 90000/90000 [==============================] - 2s 27us/sample - loss: 0.2209 - accuracy: 0.5233 - val_loss: 0.2257 - val_accuracy: 0.5256
# Epoch 94/200
# 90000/90000 [==============================] - 2s 26us/sample - loss: 0.2212 - accuracy: 0.5245 - val_loss: 0.2392 - val_accuracy: 0.5106
# Epoch 95/200
# 90000/90000 [==============================] - 2s 27us/sample - loss: 0.2202 - accuracy: 0.5233 - val_loss: 0.2319 - val_accuracy: 0.5192
# Epoch 96/200
# 90000/90000 [==============================] - 2s 26us/sample - loss: 0.2201 - accuracy: 0.5245 - val_loss: 0.2272 - val_accuracy: 0.5204
# Epoch 97/200
# 90000/90000 [==============================] - 2s 27us/sample - loss: 0.2192 - accuracy: 0.5232 - val_loss: 0.2209 - val_accuracy: 0.5320
# Epoch 98/200
# 90000/90000 [==============================] - 2s 26us/sample - loss: 0.2192 - accuracy: 0.5244 - val_loss: 0.2378 - val_accuracy: 0.5150
# Epoch 99/200
# 90000/90000 [==============================] - 3s 28us/sample - loss: 0.2185 - accuracy: 0.5239 - val_loss: 0.2277 - val_accuracy: 0.5272
# Epoch 100/200
# 90000/90000 [==============================] - 2s 27us/sample - loss: 0.2185 - accuracy: 0.5246 - val_loss: 0.2230 - val_accuracy: 0.5248
# Epoch 101/200
# 90000/90000 [==============================] - 2s 26us/sample - loss: 0.2176 - accuracy: 0.5261 - val_loss: 0.2273 - val_accuracy: 0.5186
# Epoch 102/200
# 90000/90000 [==============================] - 2s 27us/sample - loss: 0.2173 - accuracy: 0.5259 - val_loss: 0.2308 - val_accuracy: 0.5166
# Epoch 103/200
# 90000/90000 [==============================] - 2s 27us/sample - loss: 0.2171 - accuracy: 0.5262 - val_loss: 0.2248 - val_accuracy: 0.5296
# Epoch 104/200
# 90000/90000 [==============================] - 2s 28us/sample - loss: 0.2164 - accuracy: 0.5268 - val_loss: 0.2278 - val_accuracy: 0.5238
# Epoch 105/200
# 90000/90000 [==============================] - 2s 27us/sample - loss: 0.2164 - accuracy: 0.5266 - val_loss: 0.2242 - val_accuracy: 0.5172
# Epoch 106/200
# 90000/90000 [==============================] - 2s 27us/sample - loss: 0.2167 - accuracy: 0.5284 - val_loss: 0.2366 - val_accuracy: 0.5250
# Epoch 107/200
# 90000/90000 [==============================] - 2s 28us/sample - loss: 0.2160 - accuracy: 0.5273 - val_loss: 0.2232 - val_accuracy: 0.5296
# Epoch 108/200
# 90000/90000 [==============================] - 2s 28us/sample - loss: 0.2152 - accuracy: 0.5274 - val_loss: 0.2212 - val_accuracy: 0.5300
# Epoch 109/200
# 90000/90000 [==============================] - 2s 26us/sample - loss: 0.2161 - accuracy: 0.5272 - val_loss: 0.2264 - val_accuracy: 0.5284
# Epoch 110/200
# 90000/90000 [==============================] - 3s 28us/sample - loss: 0.2156 - accuracy: 0.5286 - val_loss: 0.2296 - val_accuracy: 0.5194
# Epoch 111/200
# 90000/90000 [==============================] - 3s 29us/sample - loss: 0.2151 - accuracy: 0.5276 - val_loss: 0.2213 - val_accuracy: 0.5312
# Epoch 112/200
# 90000/90000 [==============================] - 2s 28us/sample - loss: 0.2147 - accuracy: 0.5289 - val_loss: 0.2227 - val_accuracy: 0.5242
# Epoch 113/200
# 90000/90000 [==============================] - 2s 27us/sample - loss: 0.2140 - accuracy: 0.5305 - val_loss: 0.2185 - val_accuracy: 0.5252
# Epoch 114/200
# 90000/90000 [==============================] - 2s 26us/sample - loss: 0.2129 - accuracy: 0.5284 - val_loss: 0.2185 - val_accuracy: 0.5348
# Epoch 115/200
# 90000/90000 [==============================] - 2s 27us/sample - loss: 0.2136 - accuracy: 0.5304 - val_loss: 0.2167 - val_accuracy: 0.5292
# Epoch 116/200
# 90000/90000 [==============================] - 3s 28us/sample - loss: 0.2121 - accuracy: 0.5312 - val_loss: 0.2252 - val_accuracy: 0.5196
# Epoch 117/200
# 90000/90000 [==============================] - 2s 27us/sample - loss: 0.2134 - accuracy: 0.5303 - val_loss: 0.2272 - val_accuracy: 0.5114
# Epoch 118/200
# 90000/90000 [==============================] - 3s 28us/sample - loss: 0.2128 - accuracy: 0.5301 - val_loss: 0.2219 - val_accuracy: 0.5334
# Epoch 119/200
# 90000/90000 [==============================] - 3s 29us/sample - loss: 0.
200
# 90000/90000 [==============================] - 2s 27us/sample - loss: 0.2066 - accuracy: 0.5370 - val_loss: 0.2166 - val_accuracy: 0.5324
# Epoch 149/200
# 90000/90000 [==============================] - 2s 27us/sample - loss: 0.2063 - accuracy: 0.5388 - val_loss: 0.2196 - val_accuracy: 0.5412
# Epoch 150/200
# 90000/90000 [==============================] - 2s 27us/sample - loss: 0.2056 - accuracy: 0.5391 - val_loss: 0.2193 - val_accuracy: 0.5306
# Epoch 151/200
# 90000/90000 [==============================] - 3s 28us/sample - loss: 0.2056 - accuracy: 0.5373 - val_loss: 0.2156 - val_accuracy: 0.5268
# Epoch 152/200
# 90000/90000 [==============================] - 2s 27us/sample - loss: 0.2052 - accuracy: 0.5386 - val_loss: 0.2150 - val_accuracy: 0.5316
# Epoch 153/200
# 90000/90000 [==============================] - 3s 28us/sample - loss: 0.2051 - accuracy: 0.5372 - val_loss: 0.2203 - val_accuracy: 0.5298
# Epoch 154/200
# 90000/90000 [==============================] - 2s 27us/sample - loss: 0.2050 - accuracy: 0.5381 - val_loss: 0.2162 - val_accuracy: 0.5298
# Epoch 155/200
# 90000/90000 [==============================] - 2s 27us/sample - loss: 0.2054 - accuracy: 0.5375 - val_loss: 0.2259 - val_accuracy: 0.5388
# Epoch 156/200
# 90000/90000 [==============================] - 2s 26us/sample - loss: 0.2044 - accuracy: 0.5378 - val_loss: 0.2142 - val_accuracy: 0.5424
# Epoch 157/200
# 90000/90000 [==============================] - 2s 27us/sample - loss: 0.2050 - accuracy: 0.5384 - val_loss: 0.2110 - val_accuracy: 0.5392
# Epoch 158/200
# 90000/90000 [==============================] - 2s 27us/sample - loss: 0.2043 - accuracy: 0.5409 - val_loss: 0.2076 - val_accuracy: 0.5414
# Epoch 159/200
# 90000/90000 [==============================] - 2s 27us/sample - loss: 0.2033 - accuracy: 0.5385 - val_loss: 0.2157 - val_accuracy: 0.5268
# Epoch 160/200
# 90000/90000 [==============================] - 2s 28us/sample - loss: 0.2036 - accuracy: 0.5414 - val_loss: 0.2164 - val_accuracy: 0.5356
# Epoch 161/200
# 90000/90000 [==============================] - 2s 28us/sample - loss: 0.2041 - accuracy: 0.5391 - val_loss: 0.2124 - val_accuracy: 0.5392
# Epoch 162/200
# 90000/90000 [==============================] - 2s 27us/sample - loss: 0.2030 - accuracy: 0.5386 - val_loss: 0.2190 - val_accuracy: 0.5378
# Epoch 163/200
# 90000/90000 [==============================] - 2s 25us/sample - loss: 0.2041 - accuracy: 0.5400 - val_loss: 0.2147 - val_accuracy: 0.5294
# Epoch 164/200
# 90000/90000 [==============================] - 3s 29us/sample - loss: 0.2030 - accuracy: 0.5394 - val_loss: 0.2113 - val_accuracy: 0.5380
# Epoch 165/200
# 90000/90000 [==============================] - 3s 29us/sample - loss: 0.2030 - accuracy: 0.5403 - val_loss: 0.2158 - val_accuracy: 0.5464
# Epoch 166/200
# 90000/90000 [==============================] - 3s 29us/sample - loss: 0.2027 - accuracy: 0.5402 - val_loss: 0.2134 - val_accuracy: 0.5390
# Epoch 167/200
# 90000/90000 [==============================] - 3s 29us/sample - loss: 0.2043 - accuracy: 0.5383 - val_loss: 0.2152 - val_accuracy: 0.5446
# Epoch 168/200
# 90000/90000 [==============================] - 3s 29us/sample - loss: 0.2025 - accuracy: 0.5413 - val_loss: 0.2129 - val_accuracy: 0.5358
# Epoch 169/200
# 90000/90000 [==============================] - 3s 29us/sample - loss: 0.2027 - accuracy: 0.5400 - val_loss: 0.2100 - val_accuracy: 0.5472
# Epoch 170/200
# 90000/90000 [==============================] - 3s 29us/sample - loss: 0.2031 - accuracy: 0.5415 - val_loss: 0.2160 - val_accuracy: 0.5408
# Epoch 171/200
# 90000/90000 [==============================] - 3s 29us/sample - loss: 0.2017 - accuracy: 0.5420 - val_loss: 0.2106 - val_accuracy: 0.5426
# Epoch 172/200
# 90000/90000 [==============================] - 3s 29us/sample - loss: 0.2026 - accuracy: 0.5402 - val_loss: 0.2156 - val_accuracy: 0.5396
# Epoch 173/200
# 90000/90000 [==============================] - 3s 29us/sample - loss: 0.2017 - accuracy: 0.5412 - val_loss: 0.2110 - val_accuracy: 0.5430
# Epoch 174/200
# 90000/90000 [==============================] - 3s 29us/sample - loss: 0.2019 - accuracy: 0.5408 - val_loss: 0.2062 - val_accuracy: 0.5440
# Epoch 175/200
# 90000/90000 [==============================] - 3s 31us/sample - loss: 0.2015 - accuracy: 0.5426 - val_loss: 0.2058 - val_accuracy: 0.5464
# Epoch 176/200
# 90000/90000 [==============================] - 3s 30us/sample - loss: 0.2015 - accuracy: 0.5437 - val_loss: 0.2109 - val_accuracy: 0.5454
# Epoch 177/200
# 90000/90000 [==============================] - 3s 31us/sample - loss: 0.2006 - accuracy: 0.5431 - val_loss: 0.2093 - val_accuracy: 0.5358
# Epoch 178/200
# 90000/90000 [==============================] - 3s 30us/sample - loss: 0.2009 - accuracy: 0.5429 - val_loss: 0.2097 - val_accuracy: 0.5400
# Epoch 179/200
# 90000/90000 [==============================] - 3s 30us/sample - loss: 0.2009 - accuracy: 0.5434 - val_loss: 0.2175 - val_accuracy: 0.5332
# Epoch 180/200
# 90000/90000 [==============================] - 3s 30us/sample - loss: 0.2005 - accuracy: 0.5426 - val_loss: 0.2139 - val_accuracy: 0.5384
# Epoch 181/200
# 90000/90000 [==============================] - 3s 30us/sample - loss: 0.1999 - accuracy: 0.5441 - val_loss: 0.2070 - val_accuracy: 0.5364
# Epoch 182/200
# 90000/90000 [==============================] - 3s 31us/sample - loss: 0.2013 - accuracy: 0.5432 - val_loss: 0.2079 - val_accuracy: 0.5426
# Epoch 183/200
# 90000/90000 [==============================] - 3s 31us/sample - loss: 0.1995 - accuracy: 0.5437 - val_loss: 0.2106 - val_accuracy: 0.5392
# Epoch 184/200
# 90000/90000 [==============================] - 3s 30us/sample - loss: 0.2009 - accuracy: 0.5417 - val_loss: 0.2133 - val_accuracy: 0.5424
# Epoch 185/200
# 90000/90000 [==============================] - 3s 30us/sample - loss: 0.2001 - accuracy: 0.5438 - val_loss: 0.2054 - val_accuracy: 0.5378
# Epoch 186/200
# 90000/90000 [==============================] - 3s 30us/sample - loss: 0.2001 - accuracy: 0.5424 - val_loss: 0.2107 - val_accuracy: 0.5460
# Epoch 187/200
# 90000/90000 [==============================] - 3s 30us/sample - loss: 0.1994 - accuracy: 0.5433 - val_loss: 0.2118 - val_accuracy: 0.5440
# Epoch 188/200
# 90000/90000 [==============================] - 3s 30us/sample - loss: 0.2003 - accuracy: 0.5425 - val_loss: 0.2172 - val_accuracy: 0.5284
# Epoch 189/200
# 90000/90000 [==============================] - 3s 32us/sample - loss: 0.1997 - accuracy: 0.5429 - val_loss: 0.2058 - val_accuracy: 0.5352
# Epoch 190/200
# 90000/90000 [==============================] - 2s 28us/sample - loss: 0.1991 - accuracy: 0.5444 - val_loss: 0.2045 - val_accuracy: 0.5432
# Epoch 191/200
# 90000/90000 [==============================] - 2s 27us/sample - loss: 0.1996 - accuracy: 0.5446 - val_loss: 0.2082 - val_accuracy: 0.5372
# Epoch 192/200
# 90000/90000 [==============================] - 2s 26us/sample - loss: 0.1992 - accuracy: 0.5433 - val_loss: 0.2145 - val_accuracy: 0.5302
# Epoch 193/200
# 90000/90000 [==============================] - 2s 26us/sample - loss: 0.1985 - accuracy: 0.5456 - val_loss: 0.2129 - val_accuracy: 0.5426
# Epoch 194/200
# 90000/90000 [==============================] - 2s 27us/sample - loss: 0.1984 - accuracy: 0.5456 - val_loss: 0.2137 - val_accuracy: 0.5330
# Epoch 195/200
# 90000/90000 [==============================] - 2s 27us/sample - loss: 0.1985 - accuracy: 0.5429 - val_loss: 0.2079 - val_accuracy: 0.5500
# Epoch 196/200
# 90000/90000 [==============================] - 2s 27us/sample - loss: 0.1982 - accuracy: 0.5440 - val_loss: 0.2036 - val_accuracy: 0.5416
# Epoch 197/200
# 90000/90000 [==============================] - 2s 27us/sample - loss: 0.1988 - accuracy: 0.5436 - val_loss: 0.2068 - val_accuracy: 0.5460
# Epoch 198/200
# 90000/90000 [==============================] - 2s 27us/sample - loss: 0.1986 - accuracy: 0.5441 - val_loss: 0.2085 - val_accuracy: 0.5362
# Epoch 199/200
# 90000/90000 [==============================] - 2s 27us/sample - loss: 0.1978 - accuracy: 0.5437 - val_loss: 0.2072 - val_accuracy: 0.5442
# Epoch 200/200
# 90000/90000 [==============================] - 2s 27us/sample - loss: 0.1989 - accuracy: 0.5441 - val_loss: 0.2078 - val_accuracy: 0.5432

# %%
# evaluate the model
train_mse = model.evaluate(x_train, y_train, verbose=0)
test_mse = model.evaluate(x_test, y_test, verbose=0)
print('Train:', train_mse,' Test: ',test_mse)
# plot loss during training
plt.title('Loss / Mean Squared Error')
plt.plot(history.history['loss'], label='loss(train)')
plt.plot(history.history['val_loss'], label='val_loss')
plt.legend()
plt.savefig('loss.pdf',formate='pdf')
plt.show()
# Out:
# Train: [0.1937711416138543, 0.5427667]  Test:  [0.21930462054027794, 0.54269147]

# %%
score = model.evaluate(x_test, y_test, batch_size=128)
# Out:
# 5001/5001 [==============================] - 0s 6us/sample - loss: 0.2193 - accuracy: 0.5427

# %%
#prediction
y_train_predict = model.predict(x_train, batch_size = 1)
y_test_predict = model.predict(x_test, batch_size = 1)

# %%
#r2_score
r2_train = r2_score(y_train, y_train_predict)
r2_test = r2_score(y_test, y_test_predict)
print("train r2_score = ", r2_train)
print("test r2_score = ", r2_test)

#mean_squared_error
mse_train =  mean_squared_error(y_train, y_train_predict)
mse_test =  mean_squared_error(y_test, y_test_predict)
print("\ntrain mean_squared_error = ", mse_train)
print("test mean_squared_error = ", mse_test)

#mean_absolute_error
mae_train = mean_absolute_error(y_train, y_train_predict)
mae_test = mean_absolute_error(y_test, y_test_predict)
print("\ntrain mean_absolute_error", mae_train)
print("test mean_absolute_error", mae_test)
# Out:
# train r2_score =  0.8058936220066244
# test r2_score =  0.786580269482548
#
# train mean_squared_error =  0.19377114004992296
# test mean_squared_error =  0.21930462356448555
#
# train mean_absolute_error 0.29952481322868196
# test mean_absolute_error 0.31188587509446314

# %%
plt.plot(y_test[:],y_test_predict[:], "o",markerfacecolor='none')
plt.show()

# %%
#plt.plot(y_test[:],y_test_predict[:], "o")
#plt.plot(y_test_predict[:], "o", markersize=3)

y_pre_inv = StandardScaler().fit(y_test_predict).inverse_transform(y_test_predict)

plt.plot(y_test_inv,y_test_predict, "o")
#plt.plot(y_test_predict[0:100], "o", markersize=3)
#plt.show()
plt.savefig('g.pdf',formate='pdf')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-82637662dc05> in <module>
#       4 y_pre_inv = StandardScaler().fit(y_test_predict).inverse_transform(y_test_predict)
#       5
# ----> 6 plt.plot(y_test_inv,y_test_predict, "o")
#       7 #plt.plot(y_test_predict[0:100], "o", markersize=3)
#       8 #plt.show()
#
# NameError: name 'y_test_inv' is not defined

# %%
error = y_test_predict - y_test
plt.hist(error, bins = 2)
plt.xlabel("Prediction Error [MPG]")
_ = plt.ylabel("Count")
plt.savefig('error_bin.pdf',formate='pdf')

# %%
a = np.array([-1.499977111,-0.7369246482,0.511210441,-8.26997781E-002,6.553E-002,-0.56206,-0.90591,0.3578,0.3586])
a
a.shape
a
#y_test_predict = model.predict(a)
#y_pre_inv = StandardScaler().fit(y_test_predict).inverse_transform(y_test_predict)
#y_pre_inv
